# %% [markdown]
# <h1> CASA Jupyter Notebook Tutorial </h1>
#
# Here I am presenting an example of a CASA jupyter notebook as a tutorial of how to process EVN data. For explanation on how to download data please refer to the read me on the github https://github.com/jwpetley/CASA-Jupyter-Tutorial. You can either have raw FITS IDI files at this point or a CASA measurement set. Following the instructions below will allow you to convert the former to the latter if you need.
#
# ---
#
# If you would like to follow along with me I am using experiment 'EC067C'.

# %% [markdown]
# <h2> Variable Set Up to Save Typing in The Future </h2>
#
# The following cell cets up paths correctly and allows you to create variables for all your file names so that they are easier to use.

# %%
import glob
import shutil

#Removes unnecassary warnings around plots
%matplotlib inline

obsid = 'ec067c'

mypath='/home/jupyter/data/'
sys.path.append(mypath)

#Visibility data
idifiles = sorted(glob.glob(mypath+'*.IDI*'))
vis = mypath+obsid+'.ms'

print 'As cross-check for the path show which IDI files are used:'
print idifiles

#EVN archival calibration tables
AIPSflag = mypath+obsid+'.uvflg'
gcfile = mypath+'EVN.gc'
antabfile = mypath+obsid+'.antab'

#CASA calibration tables
gcaltab = mypath+obsid+'.gcal'
tsystab = mypath+obsid+'.tsys'
sbdtab = mypath+obsid+'.sbd'
mbdtab = mypath+obsid+'.mbd'
bpasstab = mypath+obsid+'.bpass'
flagtab = mypath+obsid+'.flag'

listobsfile = mypath+obsid+'.listobs'
# Out:
# As cross-check for the path show which IDI files are used:
# ['/home/jupyter/data/ec067c_1_1.IDI1']

# %% [markdown]
# <h2> Steps to create your CASA MS </h2>
#
# The following section takes you through the steps to create a CASA MS using your data set. If these files already exist we can check for them to make sure we are not overwriting.
#
# <h3> Append system temperatures </h3>
#
# Firstly we append the system temperatures needed to do VLBI calibration, go and make a coffee or something

# %%
# Local imports 
import astropy.io.fits as pyfits
from casavlbitools import fitsidi

# Check if the IDI files have a TSYS column, if not, add one
try:
    hdulist = pyfits.open(idifiles[0])
    hdu = hdulist['SYSTEM_TEMPERATURE']
    print 'TSYS table already present, skipping the append step'
except KeyError:
    print 'Appending TSYS, time to relax for a while'
    fitsidi.append_tsys(antabfile, idifiles)
# Out:
# TSYS table already present, skipping the append step

# %% [markdown]
# <h3> Automatic Flagging </h3>
#
# We extract flagging information from the AIPSFlag file for use with casa

# %%
from casavlbitools import fitsidi
fitsidi.convert_flags(AIPSflag,idifiles,outfile=flagtab)

# %% [markdown]
# <h3> Gain curve </h3>
#
# Now we extract the gain curve from the antab file that we will use for calibration later

# %%
from casavlbitools import casa as mdconvert
if os.path.isdir(gcfile)==False:
    mdconvert.convert_gaincurve(antabfile,gcfile)
else:
    print "GC conversion already done."
# Out:
# GC conversion already done.

# %% [markdown]
# <h3> Import FITS </h3>
#
# Finally we import the FITS IDI files into CASA to convert them to an MS. Importantly they will know have a system temperature column appended to them. If you already have the MS we clear any calibration or flags so that you start this notebook with a totally clean measurement set.
#
# Then we use the previous flag file we created and flag manager to show the state of the initial flagging before any flagging in calibration occurs.

# %%
if os.path.isdir(vis)==False:
    importfitsidi(fitsidifile= idifiles, vis = vis, constobsid=True, scanreindexgap_s=15.0, specframe='GEO')
else:
    print "Import already done"
    #clearcal(vis)
    #flagmanager(vis=vis,mode='restore',versionname='no_flags')
# Out:
# Import already done

# %%
flagdata(vis=vis, mode='list', inpfile=flagtab,
         reason='any', action='apply', flagbackup=True, savepars=False)
flagmanager(vis=vis,mode='rename',oldname='flagdata_1',versionname='no_flags',
        comment='Flags prior to any calibration or flagging step')
# Out:
# <button type="button"  style="background-color:red"class="btn btn-info" data-toggle="collapse" id="1604677034_49" data-target="#log1604677034_49" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Hide log</button> <div class="collapse in" id="log1604677034_49">2020-11-06 15:35:27	INFO	flagdata::::
# <br>2020-11-06 15:35:27	INFO	flagdata::::+	##########################################
# <br>2020-11-06 15:35:27	INFO	flagdata::::+	##### Begin Task: flagdata           #####
# <br>2020-11-06 15:35:27	INFO	flagdata::::	flagdata(vis="/home/jupyter/data/ec067c.ms",mode="list",autocorr=False,inpfile="/home/jupyter/data/ec067c.flag",reason="any",
# <br>2020-11-06 15:35:27	INFO	flagdata::::+	        tbuff=0.0,spw="",field="",antenna="",uvrange="",
# <br>2020-11-06 15:35:27	INFO	flagdata::::+	        timerange="",correlation="",scan="",intent="",array="",
# <br>2020-11-06 15:35:27	INFO	flagdata::::+	        observation="",feed="",clipminmax=[],datacolumn="DATA",clipoutside=True,
# <br>2020-11-06 15:35:27	INFO	flagdata::::+	        channelavg=False,chanbin=1,timeavg=False,timebin="0s",clipzeros=False,
# <br>2020-11-06 15:35:27	INFO	flagdata::::+	        quackinterval=1.0,quackmode="beg",quackincrement=False,tolerance=0.0,addantenna="",
# <br>2020-11-06 15:35:27	INFO	flagdata::::+	        lowerlimit=0.0,upperlimit=90.0,ntime="scan",combinescans=False,timecutoff=4.0,
# <br>2020-11-06 15:35:27	INFO	flagdata::::+	        freqcutoff=3.0,timefit="line",freqfit="poly",maxnpieces=7,flagdimension="freqtime",
# <br>2020-11-06 15:35:27	INFO	flagdata::::+	        usewindowstats="none",halfwin=1,extendflags=True,winsize=3,timedev="",
# <br>2020-11-06 15:35:27	INFO	flagdata::::+	        freqdev="",timedevscale=5.0,freqdevscale=5.0,spectralmax=1000000.0,spectralmin=0.0,
# <br>2020-11-06 15:35:27	INFO	flagdata::::+	        antint_ref_antenna="",minchanfrac=0.6,verbose=False,extendpols=True,growtime=50.0,
# <br>2020-11-06 15:35:27	INFO	flagdata::::+	        growfreq=50.0,growaround=False,flagneartime=False,flagnearfreq=False,minrel=0.0,
# <br>2020-11-06 15:35:27	INFO	flagdata::::+	        maxrel=1.0,minabs=0,maxabs=-1,spwchan=False,spwcorr=False,
# <br>2020-11-06 15:35:27	INFO	flagdata::::+	        basecnt=False,fieldcnt=False,name="Summary",action="apply",display="",
# <br>2020-11-06 15:35:27	INFO	flagdata::::+	        flagbackup=True,savepars=False,cmdreason="",outfile="",overwrite=True,
# <br>2020-11-06 15:35:27	INFO	flagdata::::+	        writeflags=True)
# <br>2020-11-06 15:35:27	INFO	flagdata::::	Backup original flags before applying new flags
# <br>2020-11-06 15:35:27	INFO	AgentFlagger::open	Table type is Measurement Set
# <br>2020-11-06 15:35:27	INFO	FlagVersion::saveFlagVersion	Creating new backup flag file called flagdata_1
# <br>2020-11-06 15:35:56	INFO	AgentFlagger::open	Table type is Measurement Set
# <br>2020-11-06 15:35:56	INFO	flagdata::::	List mode is active
# <br>2020-11-06 15:35:56	INFO	flagdata::::	Read 723 command(s) from file: /home/jupyter/data/ec067c.flag
# <br>2020-11-06 15:35:56	INFO	flagdata::::	Selected 723 commands from combined input list(s)
# <br>2020-11-06 15:35:57	INFO	flagdata::::	Reduced 723 timerange flags into 13 compound flags
# <br>2020-11-06 15:35:57	INFO	flagdata::::	Initializing the agents
# <br>2020-11-06 15:36:03	INFO	AgentFlagger::initAgents	There are 13 valid agents in list
# <br>2020-11-06 15:36:03	INFO	flagdata::::	Running the agentflagger tool
# <br>2020-11-06 15:36:08	INFO	FlagMSHandler::	------------------------------------------------------------------------------------
# <br>2020-11-06 15:36:08	INFO	FlagMSHandler::	Chunk = 1 [progress: 0%], Observation = 0, Array = 0, Scan = 1, Field = 0 (0017+200), Spw = 0, Channels = 32, Corrs = [ RR LL ], Total Rows = 12600
# <br>2020-11-06 15:36:08	INFO	Manual_409::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:08	INFO	Manual_52::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:08	INFO	Manual_289::chunkSummary	=> Data flagged so far 0.309524%
# <br>2020-11-06 15:36:08	INFO	Manual_567::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:08	INFO	Manual_463::chunkSummary	=> Data flagged so far 0.206349%
# <br>2020-11-06 15:36:08	INFO	Manual_619::chunkSummary	=> Data flagged so far 0.619048%
# <br>2020-11-06 15:36:08	INFO	Manual_671::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:08	INFO	Manual_0::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:08	INFO	Manual_162::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:08	INFO	FlagMSHandler::	------------------------------------------------------------------------------------
# <br>2020-11-06 15:36:08	INFO	FlagMSHandler::	Chunk = 2 [progress: 0%], Observation = 0, Array = 0, Scan = 1, Field = 0 (0017+200), Spw = 1, Channels = 32, Corrs = [ RR LL ], Total Rows = 12600
# <br>2020-11-06 15:36:08	INFO	Manual_409::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:08	INFO	Manual_52::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:08	INFO	Manual_289::chunkSummary	=> Data flagged so far 0.309524%
# <br>2020-11-06 15:36:08	INFO	Manual_567::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:08	INFO	Manual_463::chunkSummary	=> Data flagged so far 0.206349%
# <br>2020-11-06 15:36:08	INFO	Manual_619::chunkSummary	=> Data flagged so far 0.619048%
# <br>2020-11-06 15:36:08	INFO	Manual_671::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:08	INFO	Manual_0::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:08	INFO	Manual_162::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:08	INFO	FlagMSHandler::	------------------------------------------------------------------------------------
# <br>2020-11-06 15:36:08	INFO	FlagMSHandler::	Chunk = 3 [progress: 1%], Observation = 0, Array = 0, Scan = 1, Field = 0 (0017+200), Spw = 2, Channels = 32, Corrs = [ RR LL ], Total Rows = 12600
# <br>2020-11-06 15:36:08	INFO	Manual_409::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:08	INFO	Manual_52::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:08	INFO	Manual_289::chunkSummary	=> Data flagged so far 0.309524%
# <br>2020-11-06 15:36:08	INFO	Manual_567::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:08	INFO	Manual_463::chunkSummary	=> Data flagged so far 0.206349%
# <br>2020-11-06 15:36:08	INFO	Manual_619::chunkSummary	=> Data flagged so far 0.619048%
# <br>2020-11-06 15:36:08	INFO	Manual_671::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:08	INFO	Manual_0::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:08	INFO	Manual_162::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:08	INFO	FlagMSHandler::	------------------------------------------------------------------------------------
# <br>2020-11-06 15:36:08	INFO	FlagMSHandler::	Chunk = 4 [progress: 1%], Observation = 0, Array = 0, Scan = 1, Field = 0 (0017+200), Spw = 3, Channels = 32, Corrs = [ RR LL ], Total Rows = 12600
# <br>2020-11-06 15:36:08	INFO	Manual_409::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:08	INFO	Manual_52::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:08	INFO	Manual_289::chunkSummary	=> Data flagged so far 0.309524%
# <br>2020-11-06 15:36:08	INFO	Manual_567::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:08	INFO	Manual_463::chunkSummary	=> Data flagged so far 0.206349%
# <br>2020-11-06 15:36:08	INFO	Manual_619::chunkSummary	=> Data flagged so far 0.619048%
# <br>2020-11-06 15:36:08	INFO	Manual_671::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:08	INFO	Manual_0::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:08	INFO	Manual_162::chunkSummary	=> Data flagged so far 0.103175%
# <br>2020-11-06 15:36:09	INFO	FlagMSHandler::	------------------------------------------------------------------------------------

# %% [markdown]
# <h2> Time to Play with the Measurement Set! </h2>
#
# The first thing you should do with any data set is to list the observations and get an idea of what you have. I picked this experiment pretty much at random so it would be a good idea to have a look at what's inside. `listobs` is used to list the key attributes of the measurement set and we can save them to a file.

# %%
listobs(vis, listfile=listobsfile, overwrite=True)
# Out:
# ================================================================================
#            MeasurementSet Name:  /home/jupyter/data/ec067c.ms      MS Version 2
# ================================================================================
#    Observer: EC067C     Project: EC067C
# Observation: EVN
# Data records: 3401160       Total elapsed time = 9000 seconds
#    Observed from   03-Mar-2019/08:30:00.0   to   03-Mar-2019/11:00:00.0 (UTC)
#
#    ObservationID = 0         ArrayID = 0
#   Date        Timerange (UTC)          Scan  FldId FieldName             nRows     SpwIds   Average Interval(s)    ScanIntent
#   03-Mar-2019/08:30:00.0 - 08:34:00.0     1      0 0017+200                100800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               08:34:50.0 - 08:36:10.0     2      1 J0038+1856               33600  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               08:36:10.0 - 08:40:10.0     3      2 LSPMJ0036                87360  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               08:40:10.0 - 08:41:40.0     4      1 J0038+1856               32760  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               08:41:40.0 - 08:45:40.0     5      2 LSPMJ0036                87360  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               08:46:20.0 - 08:47:30.0     6      1 J0038+1856               29400  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               08:47:30.0 - 08:51:30.0     7      2 LSPMJ0036                87360  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               08:51:30.0 - 08:53:00.0     8      1 J0038+1856               32760  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               08:53:00.0 - 08:57:00.0     9      2 LSPMJ0036                87360  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               08:57:40.0 - 08:58:50.0    10      1 J0038+1856               25480  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               08:58:50.0 - 09:02:50.0    11      2 LSPMJ0036                87360  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               09:02:50.0 - 09:04:20.0    12      1 J0038+1856               32760  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               09:04:20.0 - 09:08:20.0    13      2 LSPMJ0036                87360  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               09:09:00.0 - 09:10:10.0    14      1 J0038+1856               29400  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               09:10:10.0 - 09:14:10.0    15      2 LSPMJ0036               100800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               09:14:10.0 - 09:15:40.0    16      1 J0038+1856               37800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               09:15:40.0 - 09:19:40.0    17      2 LSPMJ0036               100800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               09:20:20.0 - 09:21:30.0    18      1 J0038+1856               29400  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               09:21:30.0 - 09:25:30.0    19      2 LSPMJ0036               100800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               09:25:30.0 - 09:27:00.0    20      1 J0038+1856               37800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               09:27:00.0 - 09:31:00.0    21      2 LSPMJ0036               100800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               09:31:40.0 - 09:32:50.0    22      1 J0038+1856               25480  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               09:32:50.0 - 09:36:50.0    23      2 LSPMJ0036                87360  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               09:36:50.0 - 09:38:20.0    24      1 J0038+1856               32760  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               09:38:20.0 - 09:42:20.0    25      2 LSPMJ0036                87360  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               09:43:00.0 - 09:44:10.0    26      1 J0038+1856               25480  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               09:44:10.0 - 09:48:10.0    27      2 LSPMJ0036               100800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               09:48:10.0 - 09:49:40.0    28      1 J0038+1856               37800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               09:49:40.0 - 09:53:40.0    29      2 LSPMJ0036               100800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               09:54:20.0 - 09:55:30.0    30      1 J0038+1856               29400  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               09:55:30.0 - 09:59:30.0    31      2 LSPMJ0036               100800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               09:59:30.0 - 10:01:00.0    32      1 J0038+1856               37800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               10:01:00.0 - 10:05:00.0    33      2 LSPMJ0036               100800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               10:05:40.0 - 10:06:50.0    34      1 J0038+1856               29400  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               10:06:50.0 - 10:10:50.0    35      2 LSPMJ0036               100800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               10:10:50.0 - 10:12:20.0    36      1 J0038+1856               37800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               10:12:20.0 - 10:16:20.0    37      2 LSPMJ0036               100800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               10:17:00.0 - 10:18:10.0    38      1 J0038+1856               29400  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               10:18:10.0 - 10:22:10.0    39      2 LSPMJ0036               100800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               10:22:10.0 - 10:23:40.0    40      1 J0038+1856               37800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               10:23:40.0 - 10:27:40.0    41      2 LSPMJ0036               100800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               10:28:20.0 - 10:29:30.0    42      1 J0038+1856               29400  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               10:29:30.0 - 10:33:30.0    43      2 LSPMJ0036               100800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               10:33:30.0 - 10:35:00.0    44      1 J0038+1856               37800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               10:35:00.0 - 10:39:00.0    45      2 LSPMJ0036               100800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               10:39:40.0 - 10:40:50.0    46      1 J0038+1856               29400  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               10:40:50.0 - 10:44:50.0    47      2 LSPMJ0036               100800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               10:44:50.0 - 10:46:20.0    48      1 J0038+1856               37800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               10:46:20.0 - 10:50:20.0    49      2 LSPMJ0036               100800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               10:51:00.0 - 10:52:10.0    50      1 J0038+1856               29400  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               10:52:10.0 - 10:56:10.0    51      2 LSPMJ0036               100800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#               10:56:50.0 - 11:00:00.0    52      1 J0038+1856               79800  [0,1,2,3,4,5,6,7]  [2, 2, 2, 2, 2, 2, 2, 2]
#            (nRows = Total number of rows per scan)
# Fields: 3
#   ID   Code Name                RA               Decl           Epoch        nRows
#   0         0017+200            00:19:37.854497 +20.21.45.64456 J2000       100800
#   1         J0038+1856          00:38:28.891800 +18.56.17.63100 J2000       887880
#   2         LSPMJ0036           00:36:17.264100 +18.21.12.66940 J2000      2412480
# Spectral Windows:  (8 unique spectral windows and 1 unique polarization setups)
#   SpwID  Name   #Chans   Frame   Ch0(MHz)  ChanWid(kHz)  TotBW(kHz) CtrFreq(MHz)  Corrs
#   0      none      32    GEO    4926.990       500.000     16000.0   4934.7400   RR  LL
#   1      none      32    GEO    4942.490       500.000     16000.0   4950.2400   RR  LL
#   2      none      32    GEO    4958.990       500.000     16000.0   4966.7400   RR  LL
#   3      none      32    GEO    4974.490       500.000     16000.0   4982.2400   RR  LL
#   4      none      32    GEO    4990.990       500.000     16000.0   4998.7400   RR  LL
#   5      none      32    GEO    5006.490       500.000     16000.0   5014.2400   RR  LL
#   6      none      32    GEO    5022.990       500.000     16000.0   5030.7400   RR  LL
#   7      none      32    GEO    5038.490       500.000     16000.0   5046.2400   RR  LL
# The SOURCE table is absent: see the FIELD table
# Antennas: 14:
#   ID   Name  Station   Diam.    Long.         Lat.                Offset from array center (m)                ITRF Geocentric coordinates (m)
#                                                                      East         North     Elevation               x               y               z
#   0    JB    JB        0.0  m   -002.18.14.0  +53.02.57.4         -0.0000        0.0000  6364598.7107  3822846.500650  -153801.902280  5086286.106370
#   1    WB    WB        0.0  m   +006.35.38.1  +52.43.48.0          0.0000        0.0000  6364640.4158  3828750.396980   442589.595320  5064921.763520
#   2    EF    EF        0.0  m   +006.53.01.0  +50.20.09.1          0.0000        0.0000  6365855.3514  4033947.161040   486990.880750  4900431.056470
#   3    MC    MC        0.0  m   +011.38.49.0  +44.19.41.2          0.0000        0.0000  6367735.6220  4461369.577130   919597.231580  4449559.459080
#   4    NT    NT        0.0  m   +014.59.20.6  +36.41.29.4          0.0000        0.0000  6370620.8395  4934562.726090  1321201.643130  3806484.835230
#   6    T6    T6        0.0  m   +121.08.09.6  +30.55.19.8          0.0000        0.0000  6372518.0390 -2826708.729450  4679236.839960  3274667.389400
#   7    UR    UR        0.0  m   +087.10.41.3  +43.16.46.0          0.0000        0.0000  6370093.0297   228310.014300  4631922.894460  4367064.236370
#   8    TR    TR        0.0  m   +018.33.50.6  +52.54.37.8          0.0000        0.0000  6364638.2687  3638558.155110  1221970.084640  5077036.926690
#   9    YS    YS        0.0  m   -003.05.12.7  +40.20.05.0         -0.0000        0.0000  6370140.9458  4848761.771950  -261484.077140  4123085.134490
#   10   HH    HH        0.0  m   +027.41.07.4  -25.44.20.1          0.0000       -0.0000  6375503.2288  5085442.755630  2668263.908310 -2768696.645590
#   11   SV    SV        0.0  m   +029.46.55.0  +60.22.02.0          0.0000        0.0000  6362046.4213  2730173.551450  1562442.865970  5529969.198490
#   12   ZC    ZC        0.0  m   +041.33.54.6  +43.35.44.2          0.0000        0.0000  6369116.8014  3451207.390830  3060375.494150  4391915.095930
#   13   BD    BD        0.0  m   +102.14.02.1  +51.34.59.0          0.0000        0.0000  6365805.3096  -838201.246130  3865751.558520  4987670.879140
#   14   IB    IB        0.0  m   +021.50.50.3  +57.23.05.4          0.0000        0.0000  6362992.8144  3183295.000000  1276276.000000  5359611.000000
# True
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1604693539_27" data-target="#log1604693539_27" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1604693539_27">2020-11-06 20:12:15	INFO	listobs::::
# <br>2020-11-06 20:12:15	INFO	listobs::::+	##########################################
# <br>2020-11-06 20:12:15	INFO	listobs::::+	##### Begin Task: listobs            #####
# <br>2020-11-06 20:12:15	INFO	listobs::::	listobs(vis="/home/jupyter/data/ec067c.ms",selectdata=True,spw="",field="",antenna="",
# <br>2020-11-06 20:12:15	INFO	listobs::::+	        uvrange="",timerange="",correlation="",scan="",intent="",
# <br>2020-11-06 20:12:15	INFO	listobs::::+	        feed="",array="",observation="",verbose=True,listfile="/home/jupyter/data/ec067c.listobs",
# <br>2020-11-06 20:12:15	INFO	listobs::::+	        listunfl=False,cachesize=50,overwrite=True)
# <br>2020-11-06 20:12:17	INFO	listobs::ms::summary	Writing output to file: /home/jupyter/data/ec067c.listobs
# <br>2020-11-06 20:12:17	INFO	listobs::MSMetaData::_computeScanAndSubScanProperties 	Computing scan and subscan properties...
# <br>2020-11-06 20:12:19	INFO	listobs::::	##### End Task: listobs              #####
# <br>2020-11-06 20:12:19	INFO	listobs::::+	##########################################
# </div>

# %% [markdown]
# As you can see we observed three different fields were observed as you can see by the field names. We have 8 spectral windows with a width of 500kHz. 14 antennas were used and the positions of all of them are given. Feel free to look through the listobs file in your own time and see what you can find.
#
# Let's have a look at where these antennas are located visually. We can do this using the `plotants` task. Wouldn't it be really cool if they could actually place some sort of mapping API under this (long shot request).
#
# We should now choose the reference antenna too. Looking at the plot below we see the main cluster. EF is in the centre and has great sensitivity so we will use this as the reference, this will probabaly be applicable to your data too if using EVN.

# %%
plotants(vis)
refant = 'EF'
# Out:
# Number of points being plotted: 15
# /usr/local/lib/python2.7/dist-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# /usr/local/lib/python2.7/dist-packages/matplotlib/figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1604693541_18" data-target="#log1604693541_18" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1604693541_18">2020-11-06 20:12:20	INFO	plotants::::
# <br>2020-11-06 20:12:20	INFO	plotants::::+	##########################################
# <br>2020-11-06 20:12:20	INFO	plotants::::+	##### Begin Task: plotants           #####
# <br>2020-11-06 20:12:20	INFO	plotants::::	plotants(vis="/home/jupyter/data/ec067c.ms",figfile="",antindex=False,logpos=False,exclude="",
# <br>2020-11-06 20:12:20	INFO	plotants::::+	        checkbaselines=False,title="",showgui=True)
# <br>2020-11-06 20:12:21	INFO	msmetadata_cmpt.cc::open	Performing internal consistency checks on /home/jupyter/data/ec067c.ms...
# <br>2020-11-06 20:12:21	INFO	plotants::::	Number of points being plotted: 15
# <br>2020-11-06 20:12:21	INFO	plotants::::	##### End Task: plotants             #####
# <br>2020-11-06 20:12:21	INFO	plotants::::+	##########################################
# </div>

# %% [markdown]
# <h2> A Priori Calibration </h2>
#
# Now we want to use our Tsys and Gain Curve information to apply some calibration to the data. We can use `gencal` to generate different types of calibration table and then use `applycal` to apply them to the measurement set.
#
# Let's start by plotting the data now just to see what it looks like without calibration. We also need to choose what scan we are interested in looking at. The target for this experiment was 'LSPMJ0036' so we should pick a scan involving that. Let's use scan 27 but you can choose your own.

# %%
sbdscan = '27'

plotms(vis=vis, xaxis='frequency', yaxis='phase',
    antenna=refant, correlation='ll',coloraxis='baseline', 
    scan=sbdscan,averagedata=True, avgtime='300')
# Out:
# False
# <button type="button" class="btn btn-info" data-toggle="collapse" id="1604693727_52" data-target="#log1604693727_52" onclick="if ($('#'+this.id).html()=='Show log') {$('#'+this.id).html('Hide log')} else {$('#'+this.id).html('Show log')}; return false">Show log</button> <div class="collapse" id="log1604693727_52">2020-11-06 20:14:55	INFO	plotms::::
# <br>2020-11-06 20:14:55	INFO	plotms::::+	##########################################
# <br>2020-11-06 20:14:55	INFO	plotms::::+	##### Begin Task: plotms             #####
# <br>2020-11-06 20:14:55	INFO	plotms::::	plotms(vis="/home/jupyter/data/ec067c.ms",gridrows=1,gridcols=1,rowindex=0,colindex=0,
# <br>2020-11-06 20:14:55	INFO	plotms::::+	        plotindex=0,xaxis="frequency",xdatacolumn="",xframe="",xinterp="",
# <br>2020-11-06 20:14:55	INFO	plotms::::+	        yaxis="phase",ydatacolumn="",yframe="",yinterp="",yaxislocation="",
# <br>2020-11-06 20:14:55	INFO	plotms::::+	        selectdata=True,field="",spw="",timerange="",uvrange="",
# <br>2020-11-06 20:14:55	INFO	plotms::::+	        antenna="EF",scan="27",correlation="ll",array="",observation="",
# <br>2020-11-06 20:14:55	INFO	plotms::::+	        intent="",feed="",msselect="",averagedata=True,avgchannel="",
# <br>2020-11-06 20:14:55	INFO	plotms::::+	        avgtime="300",avgscan=False,avgfield=False,avgbaseline=False,avgantenna=False,
# <br>2020-11-06 20:14:55	INFO	plotms::::+	        avgspw=False,scalar=False,transform=True,freqframe="",restfreq="",
# <br>2020-11-06 20:14:55	INFO	plotms::::+	        veldef="RADIO",shift=[0.0, 0.0],extendflag=False,extcorr=False,extchannel=False,
# <br>2020-11-06 20:14:55	INFO	plotms::::+	        iteraxis="",xselfscale=False,yselfscale=False,xsharedaxis=False,ysharedaxis=False,
# <br>2020-11-06 20:14:55	INFO	plotms::::+	        customsymbol=False,symbolshape="autoscaling",symbolsize=2,symbolcolor="0000ff",symbolfill="fill",
# <br>2020-11-06 20:14:55	INFO	plotms::::+	        symboloutline=False,coloraxis="baseline",customflaggedsymbol=False,flaggedsymbolshape="circle",flaggedsymbolsize=2,
# <br>2020-11-06 20:14:55	INFO	plotms::::+	        flaggedsymbolcolor="ff0000",flaggedsymbolfill="fill",flaggedsymboloutline=False,xconnector="",timeconnector=False,
# <br>2020-11-06 20:14:55	INFO	plotms::::+	        plotrange=[],title="",titlefont=0,xlabel="",xaxisfont=0,
# <br>2020-11-06 20:14:55	INFO	plotms::::+	        ylabel="",yaxisfont=0,showmajorgrid=False,majorwidth=1,majorstyle="",
# <br>2020-11-06 20:14:55	INFO	plotms::::+	        majorcolor="B0B0B0",showminorgrid=False,minorwidth=1,minorstyle="",minorcolor="D0D0D0",
# <br>2020-11-06 20:14:55	INFO	plotms::::+	        showlegend=False,legendposition="",plotfile="plotms_temp.png",expformat="",verbose=True,
# <br>2020-11-06 20:14:55	INFO	plotms::::+	        exprange="",highres=False,dpi=-1,width=-1,height=-1,
# <br>2020-11-06 20:14:55	INFO	plotms::::+	        overwrite=True,showgui=False,clearplots=True,callib=[''],headeritems="",
# <br>2020-11-06 20:14:55	INFO	plotms::::+	        showatm=False,showtsky=False,showimage=False)
# <br>2020-11-06 20:14:56	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2020-11-06 20:14:56	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2020-11-06 20:14:56	INFO	PlotMS::params_changed	Updating: REDRAW, MSDATA, CACHE, AXES, CANVAS, DISPLAY, PAGEHEADER, ITERATION, LOG, PLOTMS_OPTIONS.
# <br>2020-11-06 20:14:56	INFO	PlotMS::load_cache	Clearing the existing plotms cache.
# <br>2020-11-06 20:14:56	INFO	PlotMS::load_cache	START     Current memory usage: 2283.31 kilobytes.
# <br>2020-11-06 20:14:56	INFO	PlotMS::load_cache	Plotting table ec067c.ms
# <br>2020-11-06 20:14:56	INFO	PlotMS::load_cache	  Selection: antenna: EF, scan: 27, corr: ll
# <br>2020-11-06 20:14:56	INFO	PlotMS::load_cache	Data Averaging:
# <br>2020-11-06 20:14:56	INFO	PlotMS::load_cache+	 Using VECTOR averaging.
# <br>2020-11-06 20:14:56	INFO	PlotMS::load_cache+	 Time: 300 seconds.  Scan: false;  Field: false
# <br>2020-11-06 20:14:56	INFO	PlotMS::load_cache	Caching for the new plot: Phase(18):data vs. Frequency(6)...
# <br>2020-11-06 20:15:03	INFO	PlotMS::load_cache	Loading page header cache
# <br>2020-11-06 20:15:23	INFO	PlotMS::load_cache	Data selection will yield a total of 3328 plottable points (flagged and unflagged).
# <br>2020-11-06 20:15:23	INFO	PlotMS::load_cache+	The plotms cache will require an estimated 2.4544e-05 GB of memory (7.375 bytes/point).
# <br>2020-11-06 20:15:23	INFO	PlotMS::load_cache+	This is 0.00120574% of the memory avail. to CASA (2.0356 GB).
# <br>2020-11-06 20:15:25	INFO	PlotMS::load_cache	Loading chunks......
# <br>2020-11-06 20:15:27	SEVERE	plotms::::	There was a problem updating the plot.
# <br>2020-11-06 20:15:27	INFO	plotms::::	##### End Task: plotms               #####
# <br>2020-11-06 20:15:27	INFO	plotms::::+	##########################################
# </div>
